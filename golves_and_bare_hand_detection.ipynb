# %% [markdown]
# <a href="https://colab.research.google.com/github/Jayanti-Gautam/golves-and-bare-hand-detection/blob/main/golves_and_bare_hand_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
if 'COLAB_GPU'in os.environ:
     print("GPU is enabled!")
else:
     print("GPU is not enabled!")
# Out:
# GPU is enabled!

# %%
# !pip install ultralytics==8.2.0  # or omit version to get the latest
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.8/750.8 kB 29.8 MB/s eta 0:00:00
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.0 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.5/112.6 GB disk)

# %%
# %pwd
# Out:
# '/content'

# %%
# !mkdir GolvesAndBareHandDataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
from google.colab import drive
drive.unmount('/content/drive')
print("Drive unmounted.")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1568638223.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.unmount('/content/drive')
#       3 print("Drive unmounted.")
#
# AttributeError: module 'google.colab.drive' has no attribute 'unmount'

# %%
# !ls

# %%
path="/content/golvesandbarehanddataset"

# %%
# %pwd
# Out:
# '/content'

# %%
import os
os.chdir('/content/GolvesAndBareHandDataset')
# %pwd
# Out:
# '/content/GolvesAndBareHandDataset'

# %%
# !ls

# %%
# Read the content of the data.yaml file
with open('data.yaml', 'r') as f:
    data_yaml_content = f.read()

# Replace the incorrect path with the correct one
corrected_data_yaml_content = data_yaml_content.replace(
    '/content/GolvesAndBareHandDataset/gloves-and-bare-hand-dataset-2/valid/content/GolvesAndBareHandDataset/gloves-and-bare-hand-dataset-2/valid',
    '/content/GolvesAndBareHandDataset/gloves-and-bare-hand-dataset-2/valid'
)

# Write the corrected content back to the data.yaml file
with open('data.yaml', 'w') as f:
    f.write(corrected_data_yaml_content)

print("Corrected data.yaml file content:")
print(corrected_data_yaml_content)

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=data.yaml epochs=10 imgsz=640 batch=16

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="xBm4QiSS3dAYdMEHG775")
project = rf.workspace("anusha-vqvhl").project("gloves-and-bare-hand-dataset")
version = project.version(2)
dataset = version.download("yolov8")

# %%
os.chdir("/content/GolvesAndBareHandDataset/gloves-and-bare-hand-dataset-2/")

# %%
# !pip uninstall -y torch torchvision torchaudio

# %%
# !pip install torch==2.5.1 torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121

# %%
# !pip install ultralytics --upgrade

# %%
from ultralytics import YOLO

# Load model (for example YOLOv8n)
model = YOLO('yolov8n.pt')  # This should now work!

# %%
import os
os.chdir("/content/GolvesAndBareHandDataset/gloves-and-bare-hand-dataset-2/")

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=data.yaml epochs=10 imgsz=640 batch=16

# %%
# !ls '/content/GolvesAndBareHandDataset/gloves-and-bare-hand-dataset-2/runs/detect/train2/'
